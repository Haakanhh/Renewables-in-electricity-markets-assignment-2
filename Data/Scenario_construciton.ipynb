# %% [markdown]
# # Read data files

# %%
import pandas as pd

# Load the Day Ahead Prices data for DK2 in 2025 from the CSV file
df_DAprices = pd.read_csv('DayAheadPrices_DK2.csv', sep=';')

df_DAprices = df_DAprices.drop(columns=['HourUTC', 'PriceArea', 'SpotPriceEUR'])
